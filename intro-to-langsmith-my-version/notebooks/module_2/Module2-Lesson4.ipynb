# %% [markdown]
# This section was mostly about how we can analyze our perfomance of LLm and perform comparisons by selecting/filetering experiments through their tags/metadata like MODEL_NAME and see if the evaluator is underperforming or not.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Total 9 Experiments
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# My dataset public link:
# https://smith.langchain.com/public/a3b2ea5e-a61d-463b-a81c-68f54e69b39c/d
